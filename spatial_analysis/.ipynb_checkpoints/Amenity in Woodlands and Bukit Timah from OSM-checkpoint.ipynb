# %%
import osmnx as ox
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5777d9febfa7> in <module>
# ----> 1 import osmnx as ox
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'osmnx'

# %%
import requests
import json
import csv

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="SG"][admin_level=2];
(node["amenity"="clinic"](area);
 way["amenity"="clinic"](area);
 rel["amenity"="clinic"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
import numpy as np

# %%
import pandas as pd

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.55.9 ab41fea6',
#  'osm3s': {'timestamp_osm_base': '2020-02-17T10:18:02Z',
#   'timestamp_areas_base': '2020-02-17T09:45:01Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 1652500499,
#    'lat': 1.2961959,
#    'lon': 103.7869593,
#    'tags': {'addr:city': 'Singapore',
#     'addr:housenumber': '69',
#     'addr:postcode': '139961',
#     'addr:street': 'Ayer Rajah Crescent',
#     'amenity': 'clinic',
#     'healthcare': 'clinic',
#     'name': 'Dover Medical Centre',
#     'opening_hours': 'Mo-Fr 08:30-17:30',
#     'phone': '+65 67756266'}},
#   {'type': 'node',
#    'id': 1843450677,
#    'lat': 1.3125872,
#    'lon': 103.7654918,
#    'tags': {'addr:city': 'Singapore',
#     'addr:country': 'SG',
#     'addr:housenumber': '451',
#     'addr:postcode': '120451',
#     'addr:street': 'Clementi Avenue 3',
# ...

# %%
# Collect coords into list
coord = []
coords ={}
idss = []

coords['clinic'] = []
for element in data['elements']:  
  if element['type'] == 'node':
    lon = element['lon']
    lat = element['lat']
    ids = element['id']
    idss.append(ids)
    a = coord.append((lon, lat))
    coords['clinic'].append({
        'id':idss,
        'position':a
    })
    
#   elif 'center' in element:
#     lon = element['center']['lon']
#     lat = element['center']['lat']
#     coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)

# %%
# Out:
# array([[103.7869593,   1.2961959],
#        [103.7654918,   1.3125872],
#        [103.8170178,   1.2836914],
#        [103.7729194,   1.377125 ],
#        [103.909454 ,   1.3935916],
#        [103.8577221,   1.301773 ],
#        [103.88731  ,   1.3195749],
#        [103.7752254,   1.4307876],
#        [103.7307295,   1.3496231],
#        [103.747842 ,   1.3520458],
#        [103.9458598,   1.3572803],
#        [103.8941112,   1.3926934],
#        [103.8381683,   1.2799045],
#        [103.9077648,   1.3025477],
#        [103.9316066,   1.3269378],
#        [103.9592631,   1.3686674],
#        [103.9213776,   1.3277349],
#        [103.9211969,   1.3278759],
#        [103.848313 ,   1.3710916],
#        [103.8345881,   1.4172444],
#        [103.8730547,   1.3499221],
#        [103.7930402,   1.3024631],
#        [103.7930458,   1.3023049],
#        [103.7932408,   1.3023032],
#        [103.8869128,   1.3290692],
#        [103.8871937,   1.3288707],
#        [103.954022 ,   1.3521815],
# ...

# %%
# Collect coords into list
lats = []
lons = []
idss =[]


for element in data['elements']:
  if element['type'] == 'node':
    lon = element['lon']
    lons.append(lon)
    lat = element['lat']
    lats.append(lat)
    ids = element['id']
    idss.append(ids)
  elif 'center' in element:
    lon = element['center']['lon']
    lons.append(lon)
    lat = element['center']['lat']
    lats.append(lat)
    ids = element['center']['id']
    idss.append(ids)
    coords.append((lon, lat))

# %%
dictlist = {'ids':idss, 'longitude': lons, 'latitude':lats}
clinic = pd.DataFrame(dictlist)
# Out:
#   File "<ipython-input-18-682eb763e3f4>", line 1
#     dictlist = {'ids':idss, {'longitude': lons, 'latitude':lats}}
#                                                                 ^
# SyntaxError: invalid syntax

# %%
clinic['longitude'] = clinic['longitude'].astype(float)
clinic['latitude'] = clinic['latitude'].astype(float)

# %%
df.to_csv('clinic.', index=False,
# Out:
# <bound method DataFrame.to_csv of               ids   longitude  latitude
# 0    1.652500e+09  103.786959  1.296196
# 1    1.843451e+09  103.765492  1.312587
# 2    3.038817e+09  103.817018  1.283691
# 3    3.923016e+09  103.772919  1.377125
# 4    4.465899e+09  103.909454  1.393592
# 5    4.494190e+09  103.857722  1.301773
# 6    4.583784e+09  103.887310  1.319575
# 7    4.583841e+09  103.775225  1.430788
# 8    4.583842e+09  103.730729  1.349623
# 9    4.583842e+09  103.747842  1.352046
# 10   4.583842e+09  103.945860  1.357280
# 11   4.583842e+09  103.894111  1.392693
# 12   4.583842e+09  103.838168  1.279905
# 13   4.583842e+09  103.907765  1.302548
# 14   4.583842e+09  103.931607  1.326938
# 15   4.583846e+09  103.959263  1.368667
# 16   4.599780e+09  103.921378  1.327735
# 17   4.619401e+09  103.921197  1.327876
# 18   4.621782e+09  103.848313  1.371092
# 19   4.621806e+09  103.834588  1.417244
# 20   4.621806e+09  103.873055  1.349922
# 21   4.631658e+09  103.793040  1.302463
# ...

# %%
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('Doctors in Woodlands')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %%
from geojson import Feature, FeatureCollection, Point

# %%
from sys import argv
from os.path import exists
import simplejson as json

# %%
with open('bus_stops.json') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'10009': {'lat': 1.28210155945393,
#   'lng': 103.81722480263163,
#   'name': 'Bt Merah Int'},
#  '10011': {'lat': 1.2777380589964,
#   'lng': 103.83749709165197,
#   'name': 'BEF NEIL RD'},
#  '10017': {'lat': 1.27832046633393,
#   'lng': 103.83762574759974,
#   'name': 'Aft Hosp Dr'},
#  '10018': {'lat': 1.27900819665099,
#   'lng': 103.83860360621959,
#   'name': 'Outram Pk Stn Exit F/SGH'},
#  '10021': {'lat': 1.27744837946643,
#   'lng': 103.83838894560753,
#   'name': 'Blk 3'},
#  '10041': {'lat': 1.27605834770353,
#   'lng': 103.83519065305671,
#   'name': 'BEF KAMPONG BAHRU TER'},
#  '10049': {'lat': 1.27623302424393,
#   'lng': 103.83483786772155,
#   'name': 'OPP KAMPONG BAHRU TER'},
#  '10051': {'lat': 1.2774116353284,
#   'lng': 103.83214410914843,
#   'name': 'Blk 149'},
#  '10059': {'lat': 1.27739664167497,
#   'lng': 103.83275178077875,
#   'name': 'Opp Blk 149'},
#  '10061': {'lat': 1.27860472196885,
#   'lng': 103.82948638898173,
#   'name': 'Blk 140'},
# ...

# %%
code = list(data)

# %%
lons = []
for i in code:
    lon = data[i]['lng']
    lons.append(lon)

# %%
lons
# Out:
# [103.81722480263163,
#  103.83749709165197,
#  103.83762574759974,
#  103.83860360621959,
#  103.83838894560753,
#  103.83519065305671,
#  103.83483786772155,
#  103.83214410914843,
#  103.83275178077875,
#  103.82948638898173,
#  103.83008250001669,
#  103.82638920754815,
#  103.82708906887606,
#  103.82241744338572,
#  103.82165660905856,
#  103.81783962251122,
#  103.81765723225827,
#  103.8137833011436,
#  103.81370529674271,
#  103.80935410958449,
#  103.81122515087834,
#  103.82890541983913,
#  103.8285719444802,
#  103.80686549059318,
#  103.8081000223439,
#  103.83238179897589,
#  103.83283384311112,
#  103.8285292287095,
#  103.82668969231534,
#  103.82748123930962,
#  103.82346004890803,
#  103.82395833301354,
#  103.82109741719866,
#  103.82183192865197,
#  103.81903121724014,
#  103.81936618662205,
#  103.81662854691157,
#  103.81672885450702,
#  103.81144166700754,
#  103.81191424883255,
#  103.83111793441608,
#  103.83178189529583,
#  103.82788100149519,
# ...

# %%
outfile = argv

# %%
geojson = {
    "type" : "FeatureCOllection",
    "features":[
        {
            "type": "park",
            "geometry":{
                "type": "Point",
                "coordinates":[d["position"][0], d["position"][1]]
            },
            "properties":d,
        } for d in data]
}

# %%
geojson = {
    "type" : "FeatureCOllection",
    "features":[
        {
            "type": "park",
            "geometry":{
                "type": "Point",
                "coordinates":[d["position"][0], d["position"][1]]
            },
            "properties":d,
        } for d in data]
}

# %%
with open('kin_data.geojson', 'w') as outfile:
    json.dump(geojson, outfile)

# %%
features = []
with open('kindergarten.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for latitude, longitude in reader:
        latitude, longitude = map(float, (latitude, longitude))
        features.append(
            Feature(
                geometry = Point((longitude, latitude)),
                properties = {
                    'ids': ids
                    
                }
            )
        )

collection = FeatureCollection(features)
with open("GeoObs.json", "w") as f:
    f.write('%s' % collection)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-fc9e0d2c727d> in <module>()
#       2 with open('kindergarten.csv', newline='') as csvfile:
#       3     reader = csv.reader(csvfile, delimiter=',')
# ----> 4     for latitude, longitude in reader:
#       5         latitude, longitude = map(float, (latitude, longitude))
#       6         features.append(
#
# ValueError: too many values to unpack (expected 2)

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="SG"][admin_level=2];
(node["amenity"="doctors"](area);
 way["amenity"="doctors"](area);
 rel["amenity"="doctors"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
