# %%
import gensim
from gensim.models import Word2Vec
import itertools
import scipy
from scipy import spatial
from nltk.tokenize.toktok import ToktokTokenizer

# %%
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

# %%
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
model_1 = gensim.models.Word2Vec.load("new_data_glove.model")

# %%
word_vectors = model_1.wv
fname = get_tmpfile("smell_vectors_using_pretrained_glove.kv")
word_vectors.save(fname)
word_vectors = KeyedVectors.load(fname, mmap='r')

# %%
word_vectors.save("word_vectors.txt")

# %%
for key in word_vectors:
    print(word_vectors[key])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-326f0ec9ad15> in <module>
# ----> 1 for key in word_vectors:
#       2     print(word_vectors[key])
#
# ~/pilot_study/lib/python3.6/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     353             return self.get_vector(entities)
#     354
# --> 355         return vstack([self.get_vector(entity) for entity in entities])
#     356
#     357     def __contains__(self, entity):
#
# TypeError: 'int' object is not iterable

# %%
import pandas as pd

# %%
tweets_smell = pd.read_csv("tweets_smell.csv")

# %%
#replace nan with empty string
tweets_smell["all_triggers"].fillna("", inplace=True)

# %%
def get_word_vector_dict(df_column, s,n):
    dicts={}
    for i in range(s,n):
        for key in words:
            if key == df_column['all_triggers'].iloc[i]:
                dic={key:model_1[key]}
                dicts.update(dic)
    return dicts

# %%
word_dicts.update(word_dicts2)

# %%
word_dicts.update(word_dicts3)

# %%
word_dicts.update(word_dicts4)

# %%
word_dicts.update(word_dicts5)

# %%
word_dicts2 = get_word_vector_dict(tweets_smell,20,100)
# Out:
# /Users/jie/pilot_study/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
word_dicts3 = get_word_vector_dict(tweets_smell,100,150)
# Out:
# /Users/jie/pilot_study/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
word_dicts4 = get_word_vector_dict(tweets_smell,150,200)
# Out:
# /Users/jie/pilot_study/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
word_dicts5 = get_word_vector_dict(tweets_smell,200,250)
# Out:
# /Users/jie/pilot_study/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
word_dicts5
# Out:
# {'powerful': array([-0.10835069,  0.15465562, -0.46563545,  0.5662094 ,  0.53897667,
#          0.8701113 ,  0.7978063 , -0.75169724, -1.3049238 , -0.61875945,
#         -0.6143068 , -0.17075689, -3.3516724 , -0.41167548,  0.60893214,
#          0.07313412,  0.6210223 ,  0.23129235,  1.0051725 , -0.0087066 ,
#         -0.71546966,  0.48475266, -0.8255496 ,  0.23790888, -0.533159  ,
#          1.3143485 , -0.8493735 ,  0.9589892 ,  0.2046051 ,  0.8113774 ,
#          0.19722079, -0.17976637, -0.10077447, -0.20777659,  1.4159211 ,
#          0.5372134 ,  0.1887377 , -0.4324287 , -0.07551161, -0.6624351 ,
#          0.02476977, -0.31807688,  0.79343706, -0.06066026, -0.47379223,
#          0.10392644,  0.04730347,  0.34303358, -0.7569467 ,  0.32679302],
#        dtype=float32),
#  'fish': array([-2.8312406e-01, -2.7980295e-01, -2.9400712e-01, -6.7774624e-01,
#          4.1205311e-01,  1.0907579e-02, -2.4157800e-01, -1.7449470e-02,
# ...

# %%
word_dicts6 = get_word_vector_dict(tweets_smell,250,300)
# Out:
# /Users/jie/pilot_study/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
word_dicts
# Out:
# {'serai': array([ 0.00636284, -0.887972  , -0.4481475 ,  0.1547856 , -0.7235153 ,
#          0.49355224, -0.60372627,  0.12051374,  0.7504836 , -0.39801472,
#         -0.72854096, -0.7951818 , -0.18868475, -0.39996767, -0.16431904,
#          1.7070174 ,  0.01211683,  0.31652683, -2.2844176 ,  0.8208096 ,
#          1.1624737 , -1.0368316 , -0.4363898 , -1.025552  , -0.7592663 ,
#         -0.75849444, -0.3767394 , -1.206665  , -0.2594286 , -0.03944061,
#          0.5551521 , -0.42396697, -0.8320233 , -0.43717492,  0.5906741 ,
#          0.08462939, -0.709683  , -0.9952312 ,  1.3312345 ,  0.11869894,
#         -0.2390025 , -0.70297265,  0.19152501,  0.6244958 ,  0.02299819,
#          0.1533286 , -0.02467605, -0.00685367,  0.9654757 , -0.44818613],
#        dtype=float32),
#  'bunk': array([-0.59662354, -0.6855372 ,  0.2162458 ,  0.1266911 ,  0.47732973,
#         -0.72369224,  0.09832564, -0.6966856 , -0.08326712, -0.33220333,
# ...

# %%
import csv

w = csv.writer(open("word_embeddings_smell_related_dicts.csv", "w"))
for key, val in word_dicts.items():
    w.writerow([key, val])

# %%
word_dict={}
for i in range(50,100):
    for key in words:
        if key == tweets_smell['all_triggers'].iloc[i]:
            word_dic={key:model_1[key]}
            word_dict.update(word_dic)
# Out:
# {}
