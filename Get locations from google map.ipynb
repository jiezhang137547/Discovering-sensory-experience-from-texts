# %%
import pandas as pd

# %%
df = pd.read_csv("resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv")
df = df.street_name.unique()

# %%
df = list(df)

# %%
len(df)
# Out:
# 541

# %%
import googlemaps

# %%
gmaps_key = googlemaps.Client(key = "AIzaSyAoGOEKGg229cqFRGDb15kPezLH-wnoZ_E")

# %%
geocode_result = gmaps_key.geocode(df[13])

# %%
df[13]
# Out:
# 'BEDOK RESERVOIR RD'

# %%
geocode_result[0]
# Out:
# {'address_components': [{'long_name': 'Bedok Reservoir Road',
#    'short_name': 'Bedok Reservoir Rd',
#    'types': ['route']},
#   {'long_name': 'Singapore',
#    'short_name': 'Singapore',
#    'types': ['locality', 'political']},
#   {'long_name': 'Singapore',
#    'short_name': 'SG',
#    'types': ['country', 'political']}],
#  'formatted_address': 'Bedok Reservoir Rd, Singapore',
#  'geometry': {'bounds': {'northeast': {'lat': 1.3447398, 'lng': 103.9405028},
#    'southwest': {'lat': 1.3285316, 'lng': 103.902799}},
#   'location': {'lat': 1.3370403, 'lng': 103.9215479},
#   'location_type': 'GEOMETRIC_CENTER',
#   'viewport': {'northeast': {'lat': 1.3447398, 'lng': 103.9405028},
#    'southwest': {'lat': 1.3285316, 'lng': 103.902799}}},
#  'place_id': 'ChIJg8f0OFo92jERrcRqjnpwWJU',
#  'types': ['route']}

# %%
lats = []
lons = []
addresses=[]
for i in range(0, len(df), 1):
    geocode_result = gmaps_key.geocode(df[i])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        address = df[i]
        lats.append(lat)
        lons.append(lon)
        addresses.append(address)
        
        
    except:
        lat = None
        lon = None

# %%
dicts = {"location":addresses, 'lat':lats, 'lon': lons}

# %%
locations = pd.DataFrame(dicts)

# %%
locations.to_csv('property_locations',index=False)

# %%
import csv
import json

# %%
with open('bus_stops.json') as json_file:
    data = json.load(json_file)

# %%
with open('treepoi.json') as json_file:
    poi_data = json.load(json_file)

# %%
data['10011']
# Out:
# {'lat': 1.2777380589964, 'lng': 103.83749709165197, 'name': 'BEF NEIL RD'}

# %%
bus_name =data.keys()

# %%
bus_name = list(bus_name)

# %%
bus_name
# Out:
# ['10009',
#  '10011',
#  '10017',
#  '10018',
#  '10021',
#  '10041',
#  '10049',
#  '10051',
#  '10059',
#  '10061',
#  '10069',
#  '10071',
#  '10079',
#  '10081',
#  '10089',
#  '10091',
#  '10099',
#  '10101',
#  '10109',
#  '10111',
#  '10119',
#  '10121',
#  '10129',
#  '10131',
#  '10139',
#  '10141',
#  '10149',
#  '10151',
#  '10161',
#  '10169',
#  '10171',
#  '10179',
#  '10181',
#  '10189',
#  '10191',
#  '10199',
#  '10201',
#  '10209',
#  '10211',
#  '10219',
#  '10221',
#  '10229',
#  '10231',
#  '10239',
#  '10241',
#  '10249',
#  '10261',
#  '10269',
#  '10271',
#  '10279',
#  '10281',
#  '10289',
#  '10291',
#  '10299',
#  '10321',
#  '10329',
#  '10331',
#  '10339',
#  '10341',
#  '10349',
#  '10351',
#  '10359',
#  '10361',
#  '10369',
#  '10371',
#  '10379',
#  '10381',
#  '10389',
#  '10391',
#  '10399',
#  '10401',
#  '10409',
#  '10411',
#  '10419',
#  '10421',
#  '10429',
#  '10431',
#  '10439',
#  '10441',
#  '10449',
#  '10451',
#  '10459',
#  '10461',
# ...

# %%
b = [data.get(k) for k in data]

# %%
b[0]['lat']
# Out:
# 1.28210155945393

# %%
len(poi_data)
# Out:
# 1379

# %%
lats = []
lons=[]
names = []

for i in range(len(poi_data)):
    name = poi_data[i]['name']
    lat = poi_data[i]['position'][1]
    lats.append(lat)
    lon = poi_data[i]['position'][0]
    lons.append(lon)
    names.append(name)

# %%
park_poi = {'park': names, 'lat': lats, 'lon':lons}
park = pd.DataFrame(park_poi)

# %%
park.head()
# Out:
#                            park      lat        lon
# 0           North Bridge Garden  1.30411  103.86215
# 1                   Istana Park  1.29926  103.84384
# 2           Toa Payoh Town Park  1.33058  103.84797
# 3                 Kim Seng Park  1.29284  103.83496
# 4  Mount Sinai Plain Playground  1.31571  103.78122

# %%
lats = []
lons=[]

for i in range(len(b)):
    lat = b[i]['lat']
    lats.append(lat)
    lon = b[i]['lng']
    lons.append(lon)

# %%
bus_stop = {'code': bus_name, 'lat': lats, 'lon':lons}
bus_stop_location = pd.DataFrame(bus_stop)

# %%
bus_stop_location.head()
# Out:
#     code       lat         lon
# 0  10009  1.282102  103.817225
# 1  10011  1.277738  103.837497
# 2  10017  1.278320  103.837626
# 3  10018  1.279008  103.838604
# 4  10021  1.277448  103.838389

# %%
a = bus_stop_location['lon'][bus_stop_location['code'] == '10009']

# %%
a
# Out:
# 0    103.817225
# Name: lon, dtype: float64

# %%
passager = pd.read_csv('origin_destination_bus_201912.csv')

# %%
passager['ORIGIN_PT_CODE'][1]
# Out:
# 1239

# %%
coor_lats=[]
coor_lons=[]
for i in range(len(passager['ORIGIN_PT_CODE'])):
    code = passager['ORIGIN_PT_CODE'][i]
    coor_lat = bus_stop_location['lat'][bus_stop_location['code'] == code]
    coor_lon = bus_stop_location['lon'][bus_stop_location['code'] == code]
    coor_lats.append(coor_lat)
    coor_lons.append(coor_lon)

# %%
park.to_csv(index=False)

# %%
bus_stop_location.to_csv(index=False)
